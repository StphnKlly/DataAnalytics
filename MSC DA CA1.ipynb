# %% [markdown]
# # MSC DA CA1
#
# # Stephen Kelly - sba23305

# %% [markdown]
# ### PEA01 Population Estimates (Persons in April)
#
# ###### The figures for 2017 - 2022 have been revised following a detailed analysis of the Census 2022.
# ###### https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/PEA01/XLSX/2007/en

# %%
from IPython.display import Image
Image(filename =r'cso_image.png', width = 600, height = 300)

# %%
import warnings
warnings.filterwarnings('ignore') # We can suppress the warnings

# %%
# IMPORTING LIBRARIES
# import python's data analysis library called pandas which is useful when you want to arrange your data in a tabular fashion 
# and perform some operations and manipulations on the data.
import pandas as pd

# %%
# Import dataset
data_frame = pd.read_excel(r"C:\Users\stphn\Documents\CCT\Assessment\PEA25_estimated_population.xlsx", sheet_name="Unpivoted")
data_frame.shape
# Out:
# (324, 6)

# %%
print(data_frame)
# Out:
#           Statistic Label  Year         Sex  \
# 0    Estimated Population  2006  Both sexes
# 1    Estimated Population  2006  Both sexes
# 2    Estimated Population  2006  Both sexes
# 3    Estimated Population  2006  Both sexes
# 4    Estimated Population  2006  Both sexes
# ..                    ...   ...         ...
# 319  Estimated Population  2023      Female
# 320  Estimated Population  2023      Female
# 321  Estimated Population  2023      Female
# 322  Estimated Population  2023      Female
# 323  Estimated Population  2023      Female
#
#                                            Citizenship      UNIT   VALUE
# 0                                        All Countries  Thousand  4232.9
# 1    EU14 excl Irl (countries in the EU pre 2004 ex...  Thousand    43.8
# 2    EU15 to EU27 (accession countries joined post ...  Thousand   132.5
# 3                                       United Kingdom  Thousand   115.5
# ...

# %%
# print values for 2006
data_frame.head(18)
# Out:
#          Statistic Label  Year         Sex  \
# 0   Estimated Population  2006  Both sexes
# 1   Estimated Population  2006  Both sexes
# 2   Estimated Population  2006  Both sexes
# 3   Estimated Population  2006  Both sexes
# 4   Estimated Population  2006  Both sexes
# 5   Estimated Population  2006  Both sexes
# 6   Estimated Population  2006        Male
# 7   Estimated Population  2006        Male
# 8   Estimated Population  2006        Male
# 9   Estimated Population  2006        Male
# 10  Estimated Population  2006        Male
# 11  Estimated Population  2006        Male
# 12  Estimated Population  2006      Female
# 13  Estimated Population  2006      Female
# 14  Estimated Population  2006      Female
# 15  Estimated Population  2006      Female
# 16  Estimated Population  2006      Female
# 17  Estimated Population  2006      Female
#
#                                           Citizenship      UNIT   VALUE
# ...
